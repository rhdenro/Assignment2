# %%
import pandas
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)
plt.rcParams["figure.figsize"] = (50,50)
# %matplotlib inline
df = pandas.read_csv('C:/Users/user/Desktop/electric_car.csv', sep=',')

df['addrdoro']=df['addrdoro'].str.split(" ").str.get(0)
df_groupby_time=df.groupby('usetime')
df_groupby_addr=df.groupby('addrdoro')
#for key, group in df_groupby_time:
#print("* key", key)
#   print("* count", len(group))
#   print(group)
#   print('\n')
#for key, group in df_groupby_addr:
#  print("* key", key)
#  print("* count", len(group))
#  print(group)
pandas.DataFrame(df_groupby_time).to_csv("C:/Users/user/Desktop/df_groupby_time.csv")
pandas.DataFrame(df_groupby_addr).to_csv("C:/Users/user/Desktop/df_groupby_addr.csv")
fig1 = plt.figure(figsize=(20,10))
axes1 = fig1.add_subplot(1,1,1)
axes1.hist(df['addrdoro'], bins=17)
fig2 = plt.figure(figsize=(20,10))
axes2 = fig2.add_subplot(1,1,1)
axes2.hist(df['chgertype'], bins=5)
# Out:
# (array([  11.,    0.,   86., 1869., 1810.]),
#  array([1., 2., 3., 4., 5., 6.]),
#  <a list of 5 Patch objects>)
